# %%
import cv2
import pytesseract
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = Image.open('./OCR_with_Python/Images/book01.jpg')
plt.imshow(img)
# img = cv2.cvtColor

# %%
# 이미지의 기울기 확인
print(pytesseract.image_to_osd(img))
# Out:
# Page number: 0
# Orientation in degrees: 0
# Rotate: 0
# Orientation confidence: 1.66
# Script: Latin
# Script confidence: 13.33
